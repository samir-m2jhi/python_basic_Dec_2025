# %% [markdown]
# <a href="https://colab.research.google.com/github/samir-m2jhi/python_basic_Dec_2025/blob/main/Python_Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Basic
# 2082/08/27  01:45 PM

# %% [markdown]
# # Video 1

# %%
a=1
b=20
print(a,b)
print("a,b")
print(id(a),id(b))
a_b=34
print(a_b)
# Out:
# 1 20
# a,b
# 11654376 11654984
# 34

# %%
# !pip install pandas
